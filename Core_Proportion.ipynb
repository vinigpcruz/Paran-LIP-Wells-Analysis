# %% [markdown]
# # Core Proportion
#
# * This notebook is used to define the core_prop function.
# * The core_prop function runs throught our interpreted well-data and outputs the following: (per data set)
#     * "core_prop_dict" containing (units:mean core proportion) values
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Importing Libraries and Data

# %%
# Importing libraries
import pandas as pd
import re

# Reading .csv
# data = pd.read_csv(r'Data/CSV/1-AV-001-PR.csv', sep=';', decimal=',') ## Dataset1
data = pd.read_csv(r'Data/CSV/1-CS-002-PR.csv', sep=';', decimal=',') ##Dataset2
data.head()
# Out:
#           Well          Unit                                  Facies  \
# 0  1-CS-002-PR  Paranapanema  Simple lava (basic | massive interior)
# 1  1-CS-002-PR  Paranapanema          Simple lava (basic | L. crust)
# 2  1-CS-002-PR  Paranapanema                          Siliciclastics
# 3  1-CS-002-PR  Paranapanema          Simple lava (basic | U. crust)
# 4  1-CS-002-PR  Paranapanema  Simple lava (basic | massive interior)
#
#    Facies Thickness  Flow thickness  Core Proportion
# 0              3.65             NaN              NaN
# 1              1.12             NaN              NaN
# 2              1.52             NaN              NaN
# 3             11.60           37.28         0.650215
# 4             24.24             NaN              NaN

# %% [markdown]
# ## Core proportion of lava flows per geochem group
# -----------------------------------------------------------------------------------------------------------------
# * This code runs throught the WellCad data and calculates the following:
#     * The mean core proportion per geochemical group.
# -----------------------------------------------------------------------------------------------------------------
# * Outputs:
#     * A core_prop_dict containing (unit: mean core proportion) values

# %%
# core_prop function

def core_prop(data, core_prop_dict):
    'Calculates the mean core proportion of lava flows in a given interpreted welldata'
    'data --> interpreted welldata pandas dataframe'
    'core_prop_dict --> empty dict which will be outputted'
    
    # defining variables:
    sum_core_prop = 0 # stores the sum of "core proportion" values.
    n = 0 # number of values per unit. Used for the mean calculation.
    
    # Filtering inputed dataframe:
    # Given the way the datafame is formatted I can just drop any rows which do not have core proportion information.
    filtered = data.dropna(subset=['Core Proportion'])
    filtered.reset_index(inplace=True)
    
    # Algorithm:
    for i in range(len(filtered)):
        if i == 0: # setting up the first iteration
            core_prop_dict[filtered['Unit'].iloc[i]] = 0
            sum_core_prop += filtered['Core Proportion'].iloc[i]
            n += 1
        else: # After first iteration
            if data['Unit'].iloc[i] == filtered['Unit'].iloc[i-1]: # If units remains the same
                sum_core_prop += filtered['Core Proportion'].iloc[i]
                n +=1
            else: # If 'unit' changes:
                if data['Unit'].iloc[i] in core_prop_dict: # If data has already been added to the dict.
                    # Adding previous value to the dict:
                    mean = sum_core_prop/n
                    core_prop_dict[filtered['Unit'].iloc[i-1]] = mean
                    # Reseting values:
                    n = 1
                    sum_core_prop = core_prop_dict[filtered['Core Proportion'].iloc[i]]
                    sum_core_prop += data['Core Proportion'].iloc[i]
                else:
                    # Calculate mean core_prop value for current unit:
                    mean = sum_core_prop/n
                    core_prop_dict[filtered['Unit'].iloc[i-1]] = mean
                    # Reset values:
                    core_prop_dict[filtered['Unit'].iloc[i]] = 0
                    n = 1
                    sum_core_prop = filtered['Core Proportion'].iloc[i]

# %%
filtered = data.dropna(subset=['Core Proportion'])
filtered.reset_index(inplace=True)
filtered.head(50)
# Out:
#     index         Well          Unit                                 Facies  \
# 0       3  1-CS-002-PR  Paranapanema         Simple lava (basic | U. crust)
# 1       7  1-CS-002-PR       Pitanga         Simple lava (basic | U. crust)
# 2      10  1-CS-002-PR       Pitanga         Simple lava (basic | U. crust)
# 3      13  1-CS-002-PR       Pitanga  Simple lava (basic | rubbly flow top)
# 4      18  1-CS-002-PR       Pitanga         Simple lava (basic | U. crust)
# 5      23  1-CS-002-PR       Pitanga         Simple lava (basic | U. crust)
# 6      27  1-CS-002-PR       Pitanga         Simple lava (basic | U. crust)
# 7      32  1-CS-002-PR       Pitanga  Simple lava (basic | rubbly flow top)
# 8      36  1-CS-002-PR       Pitanga  Simple lava (basic | rubbly flow top)
# 9      39  1-CS-002-PR       Pitanga  Simple lava (basic | rubbly flow top)
# 10     43  1-CS-002-PR       Pitanga         Simple lava (basic | U. crust)
# 11     47  1-CS-002-PR       Pitanga  Simple lava (basic | rubbly flow top)
# 12     51  1-CS-002-PR       Pitanga         Simple lava (basic | U. crust)
# 13     54  1-CS-002-PR       Pitanga         Simple lava (basic | U. crust)
# 14     58  1-CS-002-PR     Esmeralda         Simple lava (basic | U. crust)
# 15     62  1-CS-002-PR     Esmeralda         Simple lava (basic | U. crust)
# 16     66  1-CS-002-PR     Esmeralda  Simple lava (basic | rubbly flow top)
# 17     70  1-CS-002-PR     Esmeralda  Simple lava (basic | rubbly flow top)
# 18     75  1-CS-002-PR     Esmeralda         Simple lava (basic | U. crust)
# 19     78  1-CS-002-PR     Esmeralda         Simple lava (basic | U. crust)
# 20     81  1-CS-002-PR     Esmeralda         Simple lava (basic | U. crust)
# 21     85  1-CS-002-PR     Esmeralda         Simple lava (basic | U. crust)
# 22     90  1-CS-002-PR   Vale do Sol         Simple lava (basic | U. crust)
# 23     93  1-CS-002-PR   Vale do Sol         Simple lava (basic | U. crust)
# 24     97  1-CS-002-PR   Vale do Sol         Simple lava (basic | U. crust)
# 25    101  1-CS-002-PR   Vale do Sol         Simple lava (basic | U. crust)
#
#     Facies Thickness  Flow thickness  Core Proportion
# 0              11.60           37.28         0.650215
# 1               7.12           32.00         0.717500
# 2               4.91           22.80         0.666667
# 3              11.60           39.36         0.622713
# 4               2.56            6.00         0.440000
# 5               4.16           21.44         0.753731
# 6              19.57           56.13         0.619989
# 7              14.40           65.44         0.757946
# 8               9.76           34.16         0.583138
# 9               8.08           19.44         0.530864
# 10              5.04           25.52         0.746082
# 11              4.11           31.36         0.800064
# 12              5.28           26.88         0.744048
# 13              8.24           26.35         0.581025
# 14              4.80           13.33         0.555889
# 15             10.11           48.91         0.736046
# 16              4.72           11.52         0.437500
# 17              4.91           70.56         0.915675
# 18              5.12           13.36         0.485030
# 19              7.44           15.84         0.439394
# 20              4.32           12.24         0.568627
# 21              6.59           42.32         0.793951
# 22              2.88            6.64         0.409639
# 23              3.84           37.76         0.850371
# 24              7.70           38.42         0.770432
# 25              6.00           34.40         0.779070

# %%
# Testing
dictionary = {}
core_prop(data, dictionary)
print(dictionary)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [48], in <cell line: 3>()
#       1 # Testing
#       2 dictionary = {}
# ----> 3 core_prop(data, dictionary)
#       4 print(dictionary)
#
# Input In [47], in core_prop(data, core_prop_dict)
#      32     # Reseting values:
#      33     n = 1
# ---> 34     sum_core_prop = core_prop_dict[filtered['Core Proportion'].iloc[i]]
#      35     sum_core_prop += data['Core Proportion'].iloc[i]
#      36 else:
#      37     # Calculate mean core_prop value for current unit:
#
# KeyError: 0.666666667
